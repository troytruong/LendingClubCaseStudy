# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib. pyplot as plt

# %%
pd.set_option("display.max_columns", None)

# %%
df_loan = pd.read_csv("loan.csv", low_memory=False)

# %%
df_loan
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  \
# 0       36 months   10.65%       162.87     B        B2
# ...

# %%
#Read schema file of data set
loan_schema = pd.read_excel('Data_Dictionary.xlsx')

# %%
# Remove NaN rows in schema
loan_schema = loan_schema[loan_schema['LoanStatNew'].isna()==False]

# %%
#Filter columns are not in data set and need to skip these columns whereas we read and understand data set
loan_schema[loan_schema['LoanStatNew'].isin(df_loan.columns)==False]
# Out:
#                LoanStatNew                                        Description
# 21         fico_range_high  The upper boundary range the borrower’s FICO a...
# 22          fico_range_low  The lower boundary range the borrower’s FICO a...
# 37    last_fico_range_high  The upper boundary range the borrower’s last F...
# 38     last_fico_range_low  The lower boundary range the borrower’s last F...
# 110     total_rev_hi_lim             Total revolving high credit/credit limit
# 113  verified_status_joint  Indicates if the co-borrowers' joint income wa...

# %%
#Categorize variables which columns are categorical variables and which columns are numeric variables 
categorical_variables = ["addr_state", "application_type"]
numeric_variables = ["acc_now_delinq", "acc_open_past_24mths", "all_util", "annual_inc", "annual_inc_joint", "avg_cur_bal", "bc_open_to_buy", "bc_util", "chargeoff_within_12_mths", "collection_recovery_fee"]

# %%
df_loan.collection_recovery_fee.value_counts()
# Out:
# 0.0000      35935
# 2.0000         12
# 1.2000         10
# 3.7100          9
# 1.8800          8
#             ...
# 3.7900          1
# 773.4900        1
# 272.8250        1
# 1.7697          1
# 0.2300          1
# Name: collection_recovery_fee, Length: 2616, dtype: int64
